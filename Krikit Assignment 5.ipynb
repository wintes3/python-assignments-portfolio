# %%
import random
import matplotlib.pyplot as plt

# Initialize the vertices of the triangle and the plot vertices of an equilateral triangle
vertices_x = [0,1,0.5]
vertices_y=[0,0,0.866]

# Prompting the user for a seed point
while True:
    try:
        seed_x = float(input("Enter the x-coordinate of the seed point: "))
        seed_y = float(input("Enter the y-coordinate of the seed point: "))
        if isInside(0, 0, 1, 0, 0.5, 0.866, seed_x, seed_y):
            print("Valid seed point entered.")
            break
        else:
            print("The point is not inside the triangle. Please try again.")
    except ValueError:
        print("Invalid input. Please enter numerical values.")

#This is the starting point
seed=(seed_x, seed_y)

#Initialize a list for storing points, starting with seed
points_x = [seed_x]
points_y=[seed_y]

# Prompting the user for the number of steps
while True:
    try:
        num_steps = int(input("Enter the number of steps: "))
        if num_steps > 0:
            print(f"Number of steps set to {num_steps}.")
            break
        else:
            print("Please enter a positive integer.")
    except ValueError:
        print("Invalid input. Please enter a positive integer.")
        
for i in range(num_steps):
    #chooses a random vertex to move toward from the list 'vertices'
    random_integer=random.randint(0,2)
    next_vertex_x=vertices_x[random_integer]
    next_vertex_y=vertices_y[random_integer]
    #creates the next point by calculating the midpoint of the line between the previous point and the vertex
    next_point_x=(points_x[-1]+next_vertex_x)/2
    next_point_y=(points_y[-1]+next_vertex_y)/2
    #adds the new point to list of points
    points_x.append(next_point_x)
    points_y.append(next_point_y)

#plots the solution set
def plot_solution(points_x,points_y):
    plt.scatter(points_x[12:num_steps],points_y[12:num_steps])
    plt.show()

#plots points
plot_solution(points_x,points_y)
# Out:
# Enter the x-coordinate of the seed point: 0
# Enter the y-coordinate of the seed point: 0
# Valid seed point entered.
# Enter the number of steps: 500
# Number of steps set to 500.
